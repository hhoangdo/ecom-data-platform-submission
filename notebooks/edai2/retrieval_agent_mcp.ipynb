# %%
BASE_URL = "https://agent.example.invalid"
FIXTURE_ID = "chunk-0001"
MODEL_VERSION = "primary"
INDEX_VERSION = "ci-bootstrap"

# %% [markdown]
# # Retrieval agent and MCP walkthrough
#
# ## Audience
# Engineers reviewing the public retrieval contract before a deployed walkthrough.
#
# ## Prerequisites
# Know the Topic 14 parameters and the retrieval API contract.
#
# ## Learning goals
# Recognize the request and response field shapes without treating this source notebook as runtime evidence.
#
# ## Outline
# 1. Inspect the deterministic parameters.
# 2. Review the public request and response shapes.
# 3. Prepare a deployed Task 12 copy for execution.
#
# Task 12 owns execution against a deployed environment and captures the resulting Feast and pgvector chunk evidence.

# %% [markdown]
# ## Step 1: Review the public request shape
#
# The parameters above make a later executed copy reproducible. This structure-only mapping uses the public SearchRequest keys and intentionally supplies no runtime values.

# %%
retrieval_request = {
    "query": None,
    "top_k": None,
    "category": None,
    "effective_at": None,
}

# %% [markdown]
# ## Step 2: Review the public response schema
#
# This is a field-name schema only, not a response payload or runtime evidence.

# %%
retrieval_response_schema = (
    "request_id", "index_version", "embedding_model", "matches",
    "retrieval_ms", "abstained", "reason",
)

# %% [markdown]
# ## Exercise
# Name the request field that constrains result count and one response field that explains abstention.
#
# ## Answer scaffold
# Use the public field names above; leave this source notebook unexecuted.

# %%
exercise_answer_scaffold = {
    "request_field": None,
    "response_field": None,
}

# %% [markdown]
# ## Pitfalls
#
# Do not substitute fixture identifiers for validated request fields or read a schema as a runtime result.
#
# ## Optional extension
# Task 12 executes a deployed copy through retrieval MCP and records versioned Feast and pgvector chunk evidence; this source notebook intentionally remains cleared.
