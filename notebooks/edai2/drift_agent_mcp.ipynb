# %%
BASE_URL = "https://agent.example.invalid"
FIXTURE_ID = "customer-0001"
MODEL_VERSION = "primary"
FEATURE_SERVICE_VERSION = "section03-verified"

# %% [markdown]
# # Drift agent and MCP walkthrough
#
# ## Audience
# Engineers reviewing the public drift contract before a deployed walkthrough.
#
# ## Prerequisites
# Know the Topic 14 parameters and the population-drift API contract.
#
# ## Learning goals
# Recognize the request and response field shapes without treating this source notebook as runtime evidence.
#
# ## Outline
# 1. Inspect the deterministic parameters.
# 2. Review the public request and response shapes.
# 3. Prepare a deployed Task 12 copy for execution.
#
# Task 12 owns execution against a deployed environment and captures the resulting feature-health evidence.

# %% [markdown]
# ## Step 1: Review the public request shape
#
# The parameters above make a later executed copy reproducible. This structure-only mapping uses the public DriftDetectRequest keys and intentionally supplies no runtime values.

# %%
drift_request = {
    "id": None,
    "baseline_window": None,
    "candidate_window": None,
    "feature_name": None,
}

# %% [markdown]
# ## Step 2: Review the public response schema
#
# This is a field-name schema only, not a response payload or runtime evidence.

# %%
drift_response_schema = (
    "request_id", "scope", "feature_name", "window_days",
    "baseline_window", "candidate_window", "population_size",
    "candidate_day_count", "baseline_mean", "candidate_mean",
    "psi", "status", "drift_detected",
    "feature_service_version", "customer_context", "observed_at",
)

# %% [markdown]
# ## Exercise
# Name the request field that identifies a supplied fixture and one response field that records the observation time.
#
# ## Answer scaffold
# Use the public field names above; leave this source notebook unexecuted.

# %%
exercise_answer_scaffold = {
    "request_field": None,
    "response_field": None,
}

# %% [markdown]
# ## Pitfalls
#
# Do not substitute fixture identifiers for validated request fields or read a schema as a runtime result.
#
# ## Optional extension
# Task 12 executes a deployed copy through drift MCP and records verified feature-health evidence; this source notebook intentionally remains cleared.
